# %% [markdown]
# # 对数

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
# x_ = np.arange(-10.0,10.0,0.1)

# 假设x为正数
x_ = np.arange(0.,5.0,0.1)
x__ = x_[1:]
y_ = np.log2(x__)

plt.figure()
plt.plot(x__,y_,'r-')
plt.grid(True)
plt.show()
